# %%
from lib import ArcGraph
G=ArcGraph([(1,2),(1,3),(1,5),(5,7),(2,7)])
G.plot()
print(G.distance((3,1),(2,7)))
G.complete_graph(5)
G.plot()
# Out:
# 2

# %%
from scipy.stats import wasserstein_distance
wasserstein_distance([0.5, 0.25, 0.25], [0, 0.5, 0.5])
wasserstein_distance([1, 0], [0.5, 0.5])
# Out:
# 0.5

# %%
from scipy import stats
import wasserstein
u = [1,0,0,0]
v = [0,0,0,1]
dists = range(len(u))
print(stats.wasserstein_distance([0,1,2,3],[0,1,2,3], u, v))
wasserstein.distance([0,1,2,3],[0,1,2,3], u, v)
# Out:
# 3.0
# 3.0

# %%
 from hyper_graph import hyper

scenes = {
    0: ("A", "B"),
    1: ("B", "C"),
    2: ("C", "D", "F"),
    3: ("C", "E", "D", "A"),
    4: ("D", "F", "G", "B", "A", "K", "H"),
    5: ("B", "F"),
    6: ("A", "D"),
    7: ("B", "G"),
}
H = hnx.Hypergraph(scenes)
hnx.drawing.draw(H)
